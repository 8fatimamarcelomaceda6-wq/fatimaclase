# %% [markdown]
# Una cepa de $E. Coli$ tiene una tasa de crecimiento tal que un individuo se duplica cada 30 minutos.
#
# A)Calcula en cuanto tiempo esta cepa llenaría el volumen de la tierra (considerandola como una esfera gigante)
#
# B)Cubrir la superficie de la tierra
#
# C)Repite el calculo para una tasa de crecimiento
#
# i)Se duplica cada hora
#
# ii)se duplica cda 1/4 de hora

# %%
import math as mt

# %% [markdown]
# $B)$Cubrir la superficie de la tierra

# %%
EJERCICIO A
E=5e-7
t=6.371e6
N=t**3/E**3
N
# Out:
# 2.0687728224880002e+39

# %% [markdown]
# $C)$Repite el calculo para una tasa de crecimiento

# %%
LOG2(N)=t

# %%
t=mt.log2(N)
t
# Out:
# 130.6039709282774

# %% [markdown]
# $i)$Se duplica cada hora

# %%
t*2
# Out:
# 261.2079418565548

# %% [markdown]
# $ii)$ se  duplica cada  1/4  de hora

# %%
th=t/2
th
# Out:
# 65.3019854641387

# %% [markdown]
# $iii)$ Cuántos días tardará en cubrirse la tierra

# %%
td=th/24
print(td)
# Out:
# 2.720916061005779
